# %% [markdown]
# <a href="https://colab.research.google.com/github/imbdebroy/AI-ML-Python_Level1/blob/main/HF_Transformer_gpt2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers|
# Out:
# /bin/bash: -c: line 2: syntax error: unexpected end of file

# %%
from transformers import pipeline

# %%
generator = pipeline("text-generation", model= "gpt2")
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]

# %%
output = generator("Hi How are you ", max_length = 20, num_return_sequences = 1)
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)

# %%
print(output[0]['generated_text'])
# Out:
# Hi How are you !!!
#
# "Hello I'm Koko from the Tokyo area. I'm a former game designer for the Japanese game developers and am a game enthusiast. I'm a big fan of the original Super Smash Bros. and the original Mortal Kombat and I love the original Mortal Kombat game. I've always wanted to make a game that would help people to create games that they could enjoy.
#
# I'm currently working on a game called "Ani-Nan." This game will help people to get into the game world and get to know each other.
#
# The main goal of this game is to help people learn to play Smash, because it is an action game and it's fun to play with your friends.
#
# The main goal of this game is to help people get into the game world and get to know each other.
#
#
# I'm currently working on this game called "Ani-Nan." This game will help people to get into the game world and get to know each other.
#
#
# ...
